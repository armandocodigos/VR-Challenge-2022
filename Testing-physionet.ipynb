# %%
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import shutil
import posixpath

import wfdb

# %%
record = wfdb.rdrecord('neurological_status/Subject1_SpO2HR')

# %%
wfdb.plot_wfdb(record=record, title='Record a103l from PhysioNet Challenge 2015')

# %%
display(record.__dict__)
# Out:
# {'record_name': 'Subject1_SpO2HR',
#  'n_sig': 2,
#  'fs': 1,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 2299,
#  'base_time': None,
#  'base_date': None,
#  'comments': ['age: 30', 'gender: M', 'height/cm: 177', 'weight/kg: 94'],
#  'sig_name': ['SpO2', 'hr'],
#  'p_signal': array([[96.99996948, 89.00076296],
#         [96.99996948, 88.00013733],
#         [96.99996948, 87.00044252],
#         ...,
#         [94.00006104, 76.0000763 ],
#         [95.00003052, 75.00038148],
#         [95.00003052, 74.00068667]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['Subject1_SpO2HR.dat', 'Subject1_SpO2HR.dat'],
#  'fmt': ['16', '16'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [None, None],
#  'adc_gain': [10922.3333333, 1074.32786885],
#  'baseline': [-1048544, -103672],
#  'units': ['%', 'bpm'],
#  'adc_res': [16, 16],
#  'adc_zero': [0, 0],
#  'init_value': [10922, -8056],
#  'checksum': [54860, 19971],
#  'block_size': [0, 0]}

# %%
print('The sampling frequency of the record', record.fs)
# Out:
# The sampling frequency of the record 1

# %%
print(record.p_signal[:,1].shape, record.sig_len, record.units[1])
# Out:
# (2299,) 2299 bpm
